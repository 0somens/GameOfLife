# %% [markdown]
# # Md
# - Prueba 1
# - Prueba 2
# - Prueba 3
#
# ** negrita **

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
# %pip install tensorflow
# Out:
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 24.9 MB/s  0:00:12m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 98.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 72.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 61.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 50.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 68.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 89.6 MB/s  0:00:00
# ...
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 94.7 MB/s  0:00:00
# ...

# %% [markdown]
# Tarea:
# - Muestra cual es la ruta completa de nuestro directorio
# -Crea un directorio
# - Crea un archivo vacío en el directorio creado
# - Escribe el texto hola mundo en el archivo desde cmd
# - Muestra el contenido del archivo
# - Muestra los paquetes instalados: pip list -v
# - Verifica si está instalado tensorflow
# - instala el paquete advertools

# %%
# !pwd
# !ls -l
# !ls -a
# Out:
# /workspaces/GameOfLife/Ejercicios
# total 40
# -rw-rw-rw-  1 codespace codespace   793 Sep  4 04:05 CtoF.py
# -rw-rw-rw-  1 codespace codespace    80 Sep  3 17:19 CtoK.py
# -rw-rw-rw-  1 codespace codespace  1846 Aug 27 21:39 actividad31.py
# -rw-rw-rw-  1 codespace codespace  2281 Sep  3 17:13 actividad311.py
# drwxrwxrwx+ 2 codespace codespace  4096 Sep 10 17:27 newdirectorio
# -rw-rw-rw-  1 codespace codespace  1592 Sep 10 16:19 sudoku.py
# -rw-rw-rw-  1 codespace codespace 15155 Sep 10 17:28 test.ipynb
# -rw-rw-rw-  1 codespace codespace     0 Sep 10 17:27 text.txt

# %%
# !mkdir newdirectorio

# %%
# !cd /workspaces/GameOfLife/Ejercicios/newdirectorio
# !touch /workspaces/GameOfLife/Ejercicios/newdirectorio/ text

# %%
# !uname -a
# Out:
# Linux codespaces-e5deb8 6.8.0-1030-azure #35~22.04.1-Ubuntu SMP Mon May 26 18:08:30 UTC 2025 x86_64 x86_64 x86_64 GNU/Linux

# %%
# %%bash #magic comands
# ls -l
# pwd
# Out:
# total 40
# -rw-rw-rw-  1 codespace codespace   793 Sep  4 04:05 CtoF.py
# -rw-rw-rw-  1 codespace codespace    80 Sep  3 17:19 CtoK.py
# -rw-rw-rw-  1 codespace codespace  1846 Aug 27 21:39 actividad31.py
# -rw-rw-rw-  1 codespace codespace  2281 Sep  3 17:13 actividad311.py
# drwxrwxrwx+ 2 codespace codespace  4096 Sep 10 17:34 newdirectorio
# -rw-rw-rw-  1 codespace codespace  1592 Sep 10 16:19 sudoku.py
# -rw-rw-rw-  1 codespace codespace 16310 Sep 10 17:38 test.ipynb
# /workspaces/GameOfLife/Ejercicios

# %%
# !echo "hola mundo" > /workspaces/GameOfLife/Ejercicios/text

# %%
# !cat /workspaces/GameOfLife/Ejercicios//text
# Out:
# hola mundo

# %%
# !pip list -v #usa grep para ver si está tensorflow
# Out:
# Package                 Version     Location                                                  Installer
# ----------------------- ----------- --------------------------------------------------------- ---------
# absl-py                 2.3.1       /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# asttokens               3.0.0       /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# astunparse              1.6.3       /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# certifi                 2025.8.3    /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# charset-normalizer      3.4.3       /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# comm                    0.2.3       /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# debugpy                 1.8.16      /workspaces/GameOfLife/.venv/lib/python3.12/site-packages pip
# ...

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.20.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /workspaces/GameOfLife/.venv/lib/python3.12/site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google_pasta, grpcio, h5py, keras, libclang, ml_dtypes, numpy, opt_einsum, packaging, protobuf, requests, setuptools, six, tensorboard, termcolor, typing_extensions, wrapt
# Required-by:

# %%
# %pip install advertools

# %%
# !mkdir /workspaces/GameOfLife/Ejercicios/midrive

# %% [markdown]
# # Crea un programa que

# %% [markdown]
# # Crear una red neuronal
# - Crea los datos de ejemplo
# - Define la densidad
# - Seleccion de modelo
# - Optimiza
